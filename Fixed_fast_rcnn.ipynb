# %%
import sys
sys.path.append('faster-rcnn/')

from train import *

# %%
torch_vision_dir = '/home/shared/project/simple-faster-rcnn-pytorch/pretrain/torchvision_pretrain.pth'
kwargs = {'load_path': torch_vision_dir}
fixed_train(**kwargs)
# Out:
# ======user config========
# {'caffe_pretrain': False,
#  'caffe_pretrain_path': 'checkpoints/vgg16-caffe.pth',
#  'data': 'voc',
#  'debug_file': '/tmp/debugf',
#  'env': 'faster-rcnn',
#  'epoch': 14,
#  'load_path': '/home/shared/project/simple-faster-rcnn-pytorch/pretrain/torchvision_pretrain.pth',
#  'lr': 0.001,
#  'lr_decay': 0.1,
#  'max_size': 1000,
#  'min_size': 600,
#  'num_workers': 8,
#  'plot_every': 40,
#  'port': 8097,
#  'pretrained_model': 'vgg16',
#  'roi_sigma': 1.0,
#  'rpn_sigma': 3.0,
#  'test_num': 10000,
#  'test_num_workers': 8,
#  'use_adam': False,
#  'use_chainer': False,
#  'use_drop': False,
#  'voc_data_dir': '/home/shared/project/simple-faster-rcnn-pytorch/data/VOC2007/VOCdevkit/VOC2007/',
#  'weight_decay': 0.0005}
# ==========end============
# load data
# model construct completed
# load pretrained model from /home/shared/project/simple-faster-rcnn-pytorch/pretrain/torchvision_pretrain.pth
# <class 'dict'>
# 39it [00:27,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# faster-rcnn/model/faster_rcnn.py:223: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = t.autograd.Variable(at.totensor(img).float()[None], volatile=True)
# 40it [00:29,  1.37it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 79it [00:56,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 80it [00:57,  1.39it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 119it [01:24,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 120it [01:25,  1.40it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 159it [01:52,  1.42it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 160it [01:53,  1.40it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 199it [02:20,  1.42it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 200it [02:22,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 239it [02:48,  1.42it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 240it [02:50,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 279it [03:17,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 280it [03:18,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 319it [03:45,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 320it [03:46,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 359it [04:14,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 360it [04:15,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 399it [04:42,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 400it [04:44,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 439it [05:10,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 440it [05:11,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 479it [05:39,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
# ...
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 4880it [57:44,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 4919it [58:11,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 4920it [58:12,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 4959it [58:39,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 4960it [58:41,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 4999it [59:08,  1.41it/s]
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Exception in user code:
# ------------------------------------------------------------
# <class 'dict'>
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# Traceback (most recent call last):
#   File "/home/shared/anaconda3/lib/python3.6/site-packages/visdom/__init__.py", line 388, in _send
#     data=json.dumps(msg),
#   File "/home/shared/anaconda3/lib/python3.6/json/__init__.py", line 236, in dumps
#     return _default_encoder.encode(obj)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
#   File "/home/shared/anaconda3/lib/python3.6/json/encoder.py", line 180, in default
#     o.__class__.__name__)
# TypeError: Object of type 'Tensor' is not JSON serializable
# 5000it [59:09,  1.41it/s]
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# 5011it [59:17,  1.41it/s]
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-b31120c65861> in <module>()
#       1 torch_vision_dir = '/home/shared/project/simple-faster-rcnn-pytorch/pretrain/torchvision_pretrain.pth'
#       2 kwargs = {'load_path': torch_vision_dir}
# ----> 3 fixed_train(**kwargs)
#
# /home/shared/project/pytorch_quant/faster-rcnn/train.py in fixed_train(**kwargs)
#     108                 # roi confusion matrix
#     109                 trainer.vis.img('roi_cm', at.totensor(trainer.roi_cm.conf, False).float())
# --> 110         eval_result = eval(test_dataloader, faster_rcnn, test_num=opt.test_num)
#     111
#     112         if eval_result['map'] > best_map:
#
# /home/shared/project/pytorch_quant/faster-rcnn/train.py in eval(dataloader, faster_rcnn, test_num)
#      31     for ii, (imgs, sizes, gt_bboxes_, gt_labels_, gt_difficults_) in tqdm(enumerate(dataloader)):
#      32         sizes = [sizes[0][0], sizes[1][0]]
# ---> 33         pred_bboxes_, pred_labels_, pred_scores_ = faster_rcnn.predict(imgs, [sizes])
#      34         gt_bboxes += list(gt_bboxes_.numpy())
#      35         gt_labels += list(gt_labels_.numpy())
#
# /home/shared/project/pytorch_quant/faster-rcnn/model/faster_rcnn.py in predict(self, imgs, sizes, visualize)
#     222         for img, size in zip(prepared_imgs, sizes):
#     223             img = t.autograd.Variable(at.totensor(img).float()[None], volatile=True)
# --> 224             scale = img.shape[3] / size[1]
#     225             roi_cls_loc, roi_scores, rois, _ = self(img, scale=scale)
#     226             # We are assuming that batch size is 1.
#
# /home/shared/anaconda3/lib/python3.6/site-packages/torch/tensor.py in __rdiv__(self, other)
#     318
#     319     def __rdiv__(self, other):
# --> 320         return self.reciprocal() * other
#     321     __rtruediv__ = __rdiv__
#     322     __itruediv__ = _C._TensorBase.__idiv__
#
# RuntimeError: reciprocal is not implemented for type torch.LongTensor
