# %%
import sys
sys.path.append('faster-rcnn/')

from train import train

# %%
torch_vision_dir = '/home/shared/project/pytorch_quantization/fast-rcnn/data/model_data/chainer_best_model_converted_to_pytorch_0.7053.pth'
kwargs = {'load_path': torch_vision_dir}
train(**kwargs)
# Out:
# ======user config========
# {'caffe_pretrain': False,
#  'caffe_pretrain_path': 'checkpoints/vgg16-caffe.pth',
#  'data': 'voc',
#  'debug_file': '/tmp/debugf',
#  'env': 'faster-rcnn',
#  'epoch': 14,
#  'load_path': '/home/shared/project/simple-faster-rcnn-pytorch/data/model_data/chainer_best_model_converted_to_pytorch_0.7053.pth',
#  'lr': 0.001,
#  'lr_decay': 0.1,
#  'max_size': 1000,
#  'min_size': 600,
#  'num_workers': 8,
#  'plot_every': 40,
#  'port': 8097,
#  'pretrained_model': 'vgg16',
#  'roi_sigma': 1.0,
#  'rpn_sigma': 3.0,
#  'test_num': 10000,
#  'test_num_workers': 8,
#  'use_adam': False,
#  'use_chainer': False,
#  'use_drop': False,
#  'voc_data_dir': '/home/shared/project/simple-faster-rcnn-pytorch/data/VOC2007/VOCdevkit/VOC2007/',
#  'weight_decay': 0.0005}
# ==========end============
# load data
# model construct completed
# ...
